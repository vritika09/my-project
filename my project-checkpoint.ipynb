# %%
import os
import pyttsx3
import speech_recognition as sr
import pyaudio
import webbrowser

print("                                       Welcome to my tools                                           ")
pyttsx3.speak("Welcome to my tools")


print("Hello! How can I help you")
pyttsx3.speak("Hello! How can I help you")


while True:
    pyttsx3.speak("what do you want to open")
    print("what do you want to open  : ",end="")
    p=input()
    print("       ")
    
    if (("run" in p) or ("open" in p) or ("lunch" in p) or ("execute" in p)) and (("chrome" in p) or ("google chrome" in p)) and ("not" not in p)and ("never" not in p) and ("dont"not in p) and ("does not" not in p) and ("don't" not in p):
        pyttsx3.speak("opening chrome")
        os.system("chrome")
             
        
    elif (("open" in p) or ("lunch" in p) or ("run" in p) or ("execute" in p)) and ("notepad" in p)  and ("dont" not in p) and ("never" not in p) and ("not" in p)  and ("does not" not in p) and ("don't" not in p):
        pyttsx3.speak("opening notepad")
        os.system("notepad")
   
        
    elif (("open" in p) or ("run" in p) or ("execute" in p)) and (("wmplayer" in p) or ("window media player" in p)) and ("never" not in p) and ("dont" not in p) and ("not" not in p)  and ("does not" not in p) and ("don't" not in p):
        pyttsx3.speak("opening window media player")
        os.system("wmplayer")

    elif (("open" in p) or ("lunch" in p) or ("execute" in p)) and ("whatsapp" in p) and ("never" not in p) and ("dont" not in p) and ("not" not in p)  and ("does not" not in p) and ("don't" not in p):
        pyttsx3.speak("opening whatsapp")
        os.system("chrome web.whatsapp.com")

    elif (("open" in p) or ("lunch" in p) or ("execute" in p)) and (("facebook" in p) or ("Facebook" in p) or ("fb" in p) or ("FB" in p)) and ("never" not in p) and ("dont" not in p) and ("not" not in p)  and ("does not" not in p) and ("don't" not in p):
        pyttsx3.speak("opening facebook")
        os.system("chrome facebook.com")

    elif (("open" in p) or ("lunch" in p) or ("execute" in p)) and ("amazon" in p) and ("never" not in p) and ("dont" not in p) and ("not" not in p)  and ("does not" not in p) and ("don't" not in p):
        pyttsx3.speak("opening amazon")
        os.system("chrome amazon.com")

    elif (("open" in p) or ("lunch" in p) or ("execute" in p)) and ("flipkart" in p) and ("never" not in p) and ("dont" not in p) and ("not" not in p)  and ("does not" not in p) and ("don't" not in p):
        pyttsx3.speak("opening flipkart")
        os.system("chrome flipkart.com")

    
    elif (("open" in p) or ("lunch" in p) or ("execute" in p)) and (("cmd" in p) or ("command prompt" in p)) and ("never" not in p) and ("dont" not in p) and ("not" not in p)  and ("does not" not in p) and ("don't" not in p):
        pyttsx3.speak("opening cmd")
        os.system("cmd")


        
    elif (("open" in p) or ("run" in p) or ("execute" in p))  and ("control panel" in p) and ("not" not in p) and ("dont" not in p) and ("never" not in p)  and ("does not" not in p) and ("don't" not in p):
        pyttsx3.speak("opening control panel")
        os.system("control panel")
        
    elif (("open" in p) or ("run" in p) or ("lunch" in p) or ("execute" in p)) and ("excel" in p) and ("never" not in p) and ("dont" not in p) and ("not" not in p)  and ("does not" not in p) and ("don't" not in p):
        pyttsx3.speak("opening excel")
        os.system("excel")
        
        
    elif ("shutdown" in p) and ("not" not in p) and ("dont" not in p) and ("never" not in p)  and ("does not" not in p) and ("don't" not in p):
        pyttsx3.speak("shutdown system")
        os.system("shutdown /s /t 1")
        
    elif ("exit" in p) or ("quit" in p):
        pyttsx3.speak("Thank you for using my tools")
        break  
   
    else:
        print("***********dont support**********")
        pyttsx3.speak("dont support")
# Out:
#                                        Welcome to my tools
# Hello! How can I help you
# what do you want to open  : open notepad
#
# what do you want to open  : exit
